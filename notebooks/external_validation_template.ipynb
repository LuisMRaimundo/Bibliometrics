# %% [markdown]
# # External Validation Template
#
# **Status: template / pending external reference data**
#
# Do not claim equivalence to SciVal, Dimensions, Leiden Ranking, VOSviewer, Citespace, or bibliometrix until this notebook is run on real reference data with documented tolerances.
#
# Project: bibliometric/scientometric research software with OpenAlex-based normalization, percentile indicators, network analysis, entity enrichment, and semantic tooling.

# %% [markdown]
# ## 1. Load reference benchmark
#
# TODO: provide curated reference file (not downloaded automatically).

# %%
# reference = pd.read_csv("path/to/reference.csv")
raise NotImplementedError("Pending external reference data")

# %% [markdown]
# ## 2. Load system output
#
# Export from `run_analysis` / `run_online_pipeline` Excel.

# %%
# import pandas as pd
# system = pd.read_excel("output_metrics_pro.xlsx", sheet_name="Records+Metrics")
pass

# %% [markdown]
# ## 3–9. Compare metrics
#
# - Align by DOI / OpenAlex ID
# - MNCS/cf, PP top indicators, baselines, field/year, network metrics
# - Report deviations and methodological incompatibilities
